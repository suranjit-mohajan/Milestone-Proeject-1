# %% [markdown]
# ### Kaggle's Food-101 Overview
# The dataset contains a number of different subsets of the full food-101 data. The idea is to make a more exciting simple training set for image analysis than CIFAR10 or MNIST. For this reason the data includes massively downscaled versions of the images to enable quick tests. The data has been reformatted as HDF5 and specifically Keras HDF5Matrix which allows them to be easily read in. The file names indicate the contents of the file. For example
#
# - food_c101_n1000_r384x384x3.h5 means there are 101 categories represented, with n=1000 images, that have a resolution of 384x384x3 (RGB, uint8)
#
# - food_test_c101_n1000_r32x32x1.h5 means the data is part of the validation set, has 101 categories represented, with n=1000 images, that have a resolution of 32x32x1 (float32 from -1 to 1)

# %% [markdown]
# ### Challenge
# The first goal is to be able to automatically classify an unknown image using the dataset, but beyond this there are a number of possibilities for looking at what regions / image components are important for making classifications, identify new types of food as combinations of existing tags, build object detectors which can find similar objects in a full scene.

# %% [markdown]
# ### Import Tools

# %%
#!wget https://raw.githubusercontent.com/mrdbourke/tensorflow-deep-learning/main/extras/helper_functions.py
import tensorflow_datasets as tfds
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

import tensorflow as tf
import tensorflow_hub as hub
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import Image
import random
import os
import datetime
import helper_functions

# %load_ext tensorboard
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %% [markdown]
# # Confirm dataset in Tensorflow Datasets

# %%
datasets_list = tfds.list_builders() #get a list of all available datasets in TFDS
"food101" in datasets_list #check if target dataset in the list
# Out:
# True

# %% [markdown]
# # Import Dataset

# %%
(train_data, test_data), ds_info = tfds.load(

    name = "food101",
    split=["train", "validation"],
    shuffle_files=True,
    as_supervised= True, #includes labels and the data (data, tuple)
    with_info=True )
# Out:
# WARNING:absl:Found a different version 2.0.0 of dataset food101 in data_dir /Users/suranjitmohajan/tensorflow_datasets. Using currently defined version 1.0.0.
# WARNING:absl:options.experimental_threading is deprecated. Use options.threading instead.
# WARNING:absl:options.experimental_threading is deprecated. Use options.threading instead.
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 (train_data, test_data), ds_info = tfds.load(
#       2
#       3     name = "food101",
#       4     split=["train", "validation"],
#       5     shuffle_files=True,
#       6     as_supervised= True, #includes labels and the data (data, tuple)
#       7     with_info=True )
#
# File ~/anaconda3/envs/py3/lib/python3.10/site-packages/tensorflow_datasets/core/api_utils.py:52, in disallow_positional_args.<locals>.disallow_positional_args_dec(fn, instance, args, kwargs)
#      50 _check_no_positional(fn, args, ismethod, allowed=allowed)
#      51 _check_required(fn, kwargs)
# ---> 52 return fn(*args, **kwargs)
#
# File ~/anaconda3/envs/py3/lib/python3.10/site-packages/tensorflow_datasets/core/registered.py:312, in load(name, split, data_dir, batch_size, in_memory, shuffle_files, download, as_supervised, decoders, with_info, builder_kwargs, download_and_prepare_kwargs, as_dataset_kwargs, try_gcs)
#     309 as_dataset_kwargs.setdefault("in_memory", in_memory)
#     310 as_dataset_kwargs.setdefault("shuffle_files", shuffle_files)
# --> 312 ds = dbuilder.as_dataset(**as_dataset_kwargs)
#     313 if with_info:
#     314   return ds, dbuilder.info
#
# File ~/anaconda3/envs/py3/lib/python3.10/site-packages/tensorflow_datasets/core/api_utils.py:52, in disallow_positional_args.<locals>.disallow_positional_args_dec(fn, instance, args, kwargs)
#      50 _check_no_positional(fn, args, ismethod, allowed=allowed)
#      51 _check_required(fn, kwargs)
# ---> 52 return fn(*args, **kwargs)
#
# File ~/anaconda3/envs/py3/lib/python3.10/site-packages/tensorflow_datasets/core/dataset_builder.py:420, in DatasetBuilder.as_dataset(self, split, batch_size, shuffle_files, decoders, as_supervised, in_memory)
#     411 # Create a dataset for each of the given splits
#     412 build_single_dataset = functools.partial(
#     413     self._build_single_dataset,
#     414     shuffle_files=shuffle_files,
#    (...)
#     418     in_memory=in_memory,
#     419 )
# --> 420 datasets = utils.map_nested(build_single_dataset, split, map_tuple=True)
#     421 return datasets
#
# File ~/anaconda3/envs/py3/lib/python3.10/site-packages/tensorflow_datasets/core/utils/py_utils.py:136, in map_nested(function, data_struct, dict_only, map_tuple)
#     134   types.append(tuple)
#     135 if isinstance(data_struct, tuple(types)):
# --> 136   mapped = [map_nested(function, v, dict_only, map_tuple)
#     137             for v in data_struct]
#     138   if isinstance(data_struct, list):
#     139     return mapped
#
# File ~/anaconda3/envs/py3/lib/python3.10/site-packages/tensorflow_datasets/core/utils/py_utils.py:136, in <listcomp>(.0)
#     134   types.append(tuple)
#     135 if isinstance(data_struct, tuple(types)):
# --> 136   mapped = [map_nested(function, v, dict_only, map_tuple)
#     137             for v in data_struct]
#     138   if isinstance(data_struct, list):
#     139     return mapped
#
# File ~/anaconda3/envs/py3/lib/python3.10/site-packages/tensorflow_datasets/core/utils/py_utils.py:143, in map_nested(function, data_struct, dict_only, map_tuple)
#     141       return tuple(mapped)
#     142 # Singleton
# --> 143 return function(data_struct)
#
# File ~/anaconda3/envs/py3/lib/python3.10/site-packages/tensorflow_datasets/core/dataset_builder.py:489, in DatasetBuilder._build_single_dataset(self, split, shuffle_files, batch_size, decoders, as_supervised, in_memory)
#     486     dataset = tf.data.Dataset.from_tensor_slices(
#     487         next(dataset_utils.as_numpy(dataset)))
#     488 else:
# --> 489   dataset = self._as_dataset(
#     490       split=split, shuffle_files=shuffle_files, decoders=decoders)
#     492 if batch_size:
#     493   # Use padded_batch so that features with unknown shape are supported.
#     494   dataset = dataset.padded_batch(batch_size, dataset.output_shapes)
#
# File ~/anaconda3/envs/py3/lib/python3.10/site-packages/tensorflow_datasets/core/dataset_builder.py:828, in FileAdapterBuilder._as_dataset(self, split, decoders, shuffle_files)
#     821 def _as_dataset(
#     822     self,
#     823     split=splits_lib.Split.TRAIN,
#     824     decoders=None,
#     825     shuffle_files=False):
#     827   if self.version.implements(utils.Experiment.S3):
# --> 828     dataset = self._tfrecords_reader.read(
#     829         self.name, split, self.info.splits.values(), shuffle_files)
#     830   else:
#     831     # Resolve all the named split tree by real ones
#     832     read_instruction = split.get_read_instruction(self.info.splits)
#
# File ~/anaconda3/envs/py3/lib/python3.10/site-packages/tensorflow_datasets/core/tfrecords_reader.py:228, in Reader.read(self, name, instructions, split_infos, shuffle_files)
#     220 name2len = {name: sum(lengths)
#     221             for name, lengths in name2shard_lengths.items()}
#     222 read_instruction = functools.partial(
#     223     _read_single_instruction,
#     224     parse_fn=self._parser.parse_example,
#     225     name=name, path=self._path,
#     226     name2len=name2len, name2shard_lengths=name2shard_lengths,
#     227     shuffle_files=shuffle_files)
# --> 228 datasets = utils.map_nested(read_instruction, instructions, map_tuple=True)
#     229 return datasets
#
# File ~/anaconda3/envs/py3/lib/python3.10/site-packages/tensorflow_datasets/core/utils/py_utils.py:143, in map_nested(function, data_struct, dict_only, map_tuple)
#     141       return tuple(mapped)
#     142 # Singleton
# --> 143 return function(data_struct)
#
# File ~/anaconda3/envs/py3/lib/python3.10/site-packages/tensorflow_datasets/core/tfrecords_reader.py:141, in _read_single_instruction(instruction, parse_fn, name, path, name2len, name2shard_lengths, shuffle_files)
#     139 if not isinstance(instruction, ReadInstruction):
#     140   instruction = ReadInstruction.from_spec(instruction)
# --> 141 absolute_instructions = instruction.to_absolute(name2len)
#     142 files = list(itertools.chain.from_iterable([
#     143     _get_dataset_files(name, path, abs_instr, name2shard_lengths)
#     144     for abs_instr in absolute_instructions]))
#     145 if not files:
#
# File ~/anaconda3/envs/py3/lib/python3.10/site-packages/tensorflow_datasets/core/tfrecords_reader.py:447, in ReadInstruction.to_absolute(self, name2len)
#     436 def to_absolute(self, name2len):
#     437   """Translate instruction into a list of absolute instructions.
#     438
#     439   Those absolute instructions are then to be added together.
#    (...)
#     445     list of _AbsoluteInstruction instances (corresponds to the + in spec).
#     446   """
# --> 447   return [_rel_to_abs_instr(rel_instr, name2len)
#     448           for rel_instr in self._relative_instructions]
#
# File ~/anaconda3/envs/py3/lib/python3.10/site-packages/tensorflow_datasets/core/tfrecords_reader.py:447, in <listcomp>(.0)
#     436 def to_absolute(self, name2len):
#     437   """Translate instruction into a list of absolute instructions.
#     438
#     439   Those absolute instructions are then to be added together.
#    (...)
#     445     list of _AbsoluteInstruction instances (corresponds to the + in spec).
#     446   """
# --> 447   return [_rel_to_abs_instr(rel_instr, name2len)
#     448           for rel_instr in self._relative_instructions]
#
# File ~/anaconda3/envs/py3/lib/python3.10/site-packages/tensorflow_datasets/core/tfrecords_reader.py:296, in _rel_to_abs_instr(rel_instr, name2len)
#     294 split = rel_instr.splitname
#     295 if split not in name2len:
# --> 296   raise AssertionError('Requested split "%s" does not exist.' % split)
#     297 num_examples = name2len[split]
#     298 from_ = rel_instr.from_
#
# AssertionError: Requested split "validation" does not exist.

# %% [markdown]
# # Data Exploration

# %% [markdown]
# View Features

# %%
ds_info.features
# Out:
# FeaturesDict({
#     'image': Image(shape=(None, None, 3), dtype=uint8),
#     'label': ClassLabel(shape=(), dtype=int64, num_classes=101),
# })

# %% [markdown]
# Create Class names

# %%
class_names = ds_info.features["label"].names
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 class_names = ds_info.features["label"].names
#
# NameError: name 'ds_info' is not defined

# %%
train_data_samples = train_data.take(6) 

for image, label in train_data_samples:
    print(
    f"""
        Image shape: {image.shape}
        Image datatype: {image.dtype}
        Target class from Food101: (tensor form): {label}
        Class name (str form): {class_names[label.numpy()]}
    """
    )
# Out:
#         Image shape: (512, 289, 3)
#         Image datatype: <dtype: 'uint8'>
#         Target class from Food101: (tensor form): 45
#         Class name (str form): frozen_yogurt
#
#
#         Image shape: (512, 512, 3)
#         Image datatype: <dtype: 'uint8'>
#         Target class from Food101: (tensor form): 3
#         Class name (str form): beef_carpaccio
#
#
#         Image shape: (512, 384, 3)
#         Image datatype: <dtype: 'uint8'>
#         Target class from Food101: (tensor form): 26
#         Class name (str form): crab_cakes
#
#
#         Image shape: (512, 384, 3)
#         Image datatype: <dtype: 'uint8'>
#         Target class from Food101: (tensor form): 61
#         Class name (str form): lobster_roll_sandwich
#
#
#         Image shape: (382, 512, 3)
#         Image datatype: <dtype: 'uint8'>
#         Target class from Food101: (tensor form): 21
#         Class name (str form): chocolate_cake
#
#
#         Image shape: (385, 512, 3)
#         Image datatype: <dtype: 'uint8'>
#         Target class from Food101: (tensor form): 4
#         Class name (str form): beef_tartare

# %%
tf.reduce_min(image), tf.reduce_max(image)
# Out:
# (<tf.Tensor: shape=(), dtype=uint8, numpy=0>,
#  <tf.Tensor: shape=(), dtype=uint8, numpy=255>)

# %% [markdown]
# ### Observations:
#    - tensor values are not scaled
#    - class names are label encoded
#    - dtype can be changed from uint8 to int64
#    - image shapes are inconsistent

# %% [markdown]
# ### View images and labels

# %%
def view_images(train = True, validation = False, test = False):
   
    '''
    Displays 12 images from specified dataset with their true labels as titles
    
    '''

    if test:
        data_samples = test_data.take(12) 
    
    else:
        data_samples = train_data.take(12)            
                
                
    plt.figure(figsize=(15,13))

    for i, data in enumerate(data_samples):
        image, label = data
        plt.subplot(4, 4, i+1)
        plt.imshow(image)
        plt.title(class_names[label].upper())
        plt.xticks([])
        plt.yticks([])

# %%
view_images(test=True)

# %% [markdown]
# # Preprocess Data
#
# - changes to be made to the data
#
#  - tensor values to be scaled
#  - dtype is uint8
#       - can be changed to float32 or for mixed precision(float16 and float32)
#  - image shapes are inconsistent
#       - can be changed to (224)
#  - store data in batches of size 32
#
#
# #### Key note:
# If we use data on an EfficientNetBX pretrained model, no need to rescale (rescaling is built in)

# %%
def preprocess_data(image, label, img_shape = 224, scale = False):
    
    '''
    Converts image datatype to "float32", reshapes image to [img_shape, img_shape] 
    '''   
    
    #reshape image
    image = tf.image.resize(image, [img_shape, img_shape])
    
    #change image dtype
    image = tf.cast(image, tf.float32)
    
    
    return image, label

# %% [markdown]
# # Data Augmentation

# %%
from tensorflow.keras.layers.experimental import preprocessing

data_augmentation = tf.keras.Sequential([
  preprocessing.RandomFlip("horizontal"),
  preprocessing.RandomRotation(0.2),
  preprocessing.RandomZoom(0.2),
  preprocessing.RandomHeight(0.2),
  preprocessing.RandomWidth(0.2),
  # preprocessing.Rescaling(1./255) (nor required for EfficientNet)
],
  name = "data_augmentaion"
)

# %% [markdown]
# ### Normal Image

# %%
for items in train_data.take(1):
  image, label = items
plt.imshow(image);
plt.xticks([]);
plt.yticks([]);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 for items in train_data.take(1):
#       2   image, label = items
#       3 plt.imshow(image);
#
# NameError: name 'train_data' is not defined

# %% [markdown]
# ### Augmented Image

# %%
image_aug = data_augmentation(image, training = True)
plt.imshow(image_aug/255.);
plt.xticks([]);
plt.yticks([]);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 image_aug = data_augmentation(image, training = True)
#       2 plt.imshow(image_aug/255.);
#       3 plt.xticks([]);
#
# NameError: name 'data_augmentation' is not defined

# %% [markdown]
# # Batch and prepare Datasets
#
# - Following Tensorflow's best practices summary (to speed up data loading time)
#     https://www.tensorflow.org/guide/data_performance
#
#
# ## Prepare Train Dataset
#
#
# - Map train_data to preprocessing function
#     - utilize all compute power from GPU (num_parallel_calls = tf.data.AUTOTUNE)
#
# - Shuffle train data
#     - how many at at time? (set buffer size to 1000)
#
# - Turn into batches (batch_size = 32)
# - Prefetch for faster loading (getting next batch ready while finding patterns on current batch)
#      - buffer_size = tf.data.AUTOTUNE

# %%
train_data = train_data.map(preprocess_data, num_parallel_calls=tf.data.AUTOTUNE)

train_data = train_data.shuffle(buffer_size=1000).batch(32).prefetch(buffer_size=tf.data.AUTOTUNE)

# %% [markdown]
# ## Prepare Test Dataset
#
# - Map test_data to preprocessing function
#     - utilize all compute power from GPU (num_parallel_calls = tf.data.AUTOTUNE)
#
# - Turn into batches (batch_size = 32)
#
# - Prefetch for faster loading (getting next batch ready while finding patterns on current batch)
#     - buffer_size = tf.data.AUTOTUNE

# %%
test_data = test_data.map(preprocess_data, num_parallel_calls=tf.data.AUTOTUNE)

test_data = test_data.batch(32).prefetch(buffer_size=tf.data.AUTOTUNE)

# %% [markdown]
# # Create Modelling Callbacks
#
# - Tensorboard callback
#     - to log training results
# - ModelCheckpoint callback
#     - to save model's progress after feature extraction
#     - save model's best performace on epoch with highest val accuracy
# - Early stopping
#     - to stop model training early is a certain metric stops improving
#     - stop when val_accuracy hasnt improved within 3 epochs

# %%
#import tensorboard_callback from helper functions
from helper_functions import create_tensorboard_callback
 

#create model checkpoint
model_checkpoint_path = "model_checkpoints/cp.ckpt"
model_checkpoint = tf.keras.callbacks.ModelCheckpoint(model_checkpoint_path,
                                                     monitor = "val_acc",
                                                     save_weights_only=True,
                                                     verbose = 1)


model_early_stopping = tf.keras.callbacks.EarlyStopping(monitor="val_accuracy",
                                                 patience=3)

# %% [markdown]
# # Mixed Precision Training
#
# - This is used to utilize the combination of float16 and float 32 dtypes to speed up model's performance.
# - The layers the can or should use mixed precision will do that for a speed up

# %%
from tensorflow.keras import mixed_precision

mixed_precision.set_global_policy(policy="mixed_float16") 
#sets global data policy to mixed precision

mixed_precision.global_policy() # should output "mixed_float16"
# Out:
# <Policy "mixed_float16">

# %%
for layer in model.layers:
    print(layer.name, layer.trainable, layer.dtype, layer.dtype_policy)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-0124ac216530> in <cell line: 1>()
# ----> 1 for layer in model.layers:
#       2     print(layer.name, layer.trainable, layer.dtype, layer.dtype_policy)
#
# NameError: name 'model' is not defined

# %% [markdown]
# Observations:
#
#   - layer.name - human readable name
#
#   - layer.trainable - is the layer trainable
#
#   - layer.dtype - the data type a layer stores ite variables in
#
#   - layer.dtype_policy - the data type policy a layer computes on its variables with
#
#
# Key note: layers which can take benefit of float16, thus store more tensors in the GPU memory will do so.

# %% [markdown]
# # Running Model Experiments
# 1. model_1 - Feature Extraction Transfer learning (EfficientNetB0) with Data Augmentation
# 2. model_1 - Finetuning
# 3. model_2 - Feature Extraction Transfer learning (EfficientNetB0) without Data Augmentation
# 4. model_2 - Finetuning

# %% [markdown]
# # Create Model_1

# %%
from tensorflow.keras import layers
from tensorflow.keras.layers.experimental import preprocessing

#create base model
input_shape = (224,224,3)
base_model = tf.keras.applications.EfficientNetB0(include_top=False)
#set to false because we are customizing model (adding more layers) 
 
base_model.trainable = False
#when training our model with train data, we want the feature extraction model 
#to keep that preexisting patters not get trained more


#Create Functional model 

inputs = tf.keras.layers.Input(shape=input_shape, name = "input_layer")
print(inputs.shape)

# Add in data augmentation Sequential model as a layer
x = data_augmentation(inputs, training = True) 
print(x.shape)

#note: efficientnet has sclaing built in, if that was not the case
#x = preprocessing.Rescaling(1./255)(inputs)

x = base_model(x, training = False) #setting model as inference again
print(x.shape)


x = tf.keras.layers.GlobalAveragePooling2D(name = "global_average_pooling_layer")(x)
print(x.shape)


x = layers.Dense(len(class_names))(x) 
# one neuron per class 

# Separate activation of output layer so we can output float32 activations
outputs = layers.Activation("softmax", dtype=tf.float32, name="softmax_float32")(x) 

model_1 = tf.keras.Model(inputs, outputs)
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 [==============================] - 2s 0us/step
# (None, 224, 224, 3)
# (None, None, None, 3)
# (None, None, None, 1280)
# (None, 1280)

# %% [markdown]
# ## Compile Model_1

# %%
model_1.compile(loss = tf.keras.losses.SparseCategoricalCrossentropy(),
             optimizer = tf.keras.optimizers.Adam(),
             metrics="accuracy")

# %% [markdown]
# ## Model_1 Summary

# %%
model_1.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_layer (InputLayer)    [(None, 224, 224, 3)]     0
#
#  data_augmentaion (Sequentia  (None, None, 3)          0
#  l)
#
#  efficientnetb0 (Functional)  (None, None, None, 1280)  4049571
#
#  global_average_pooling_laye  (None, 1280)             0
#  r (GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 101)               129381
#
#  softmax_float32 (Activation  (None, 101)              0
#  )
#
# =================================================================
# Total params: 4,178,952
# Trainable params: 129,381
# Non-trainable params: 4,049,571
# _________________________________________________________________

# %% [markdown]
# ## Fit Model_1

# %%
# Turn off all warnings except for errors
tf.get_logger().setLevel('ERROR')


initial_epochs = 5
model_1_history = model_1.fit(train_data, 
                                                     epochs=initial_epochs,
                                                     steps_per_epoch=len(train_data),
                                                     validation_data=test_data,
                                                     validation_steps=int(0.25 * len(test_data)),
                                                     callbacks=[create_tensorboard_callback("training_logs", 
                                                                                            "Model_1_efficientnetb0_feature_extract"),
                                                                model_checkpoint,
                                                               model_early_stopping])
# Out:
# Saving TensorBoard log files to: training_logs/Model_1_efficientnetb0_feature_extract/20230402-024716
# Epoch 1/5
#  157/2368 [>.............................] - ETA: 13:58 - loss: 3.6570 - accuracy: 0.2134
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-30-9d9a5ecd24e4> in <cell line: 6>()
#       4
#       5 initial_epochs = 5
# ----> 6 model_1_history = model_1.fit(train_data,
#       7                                                      epochs=initial_epochs,
#       8                                                      steps_per_epoch=len(train_data),
#
# /usr/local/lib/python3.9/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.9/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1683                         ):
#    1684                             callbacks.on_train_batch_begin(step)
# -> 1685                             tmp_logs = self.train_function(iterator)
#    1686                             if data_handler.should_sync:
#    1687                                 context.async_wait()
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     892
#     893       with OptionalXlaContext(self._jit_compile):
# --> 894         result = self._call(*args, **kwds)
#     895
#     896       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     924       # In this case we have created variables on the first call, so we run the
#     925       # defunned version which is guaranteed to never create variables.
# --> 926       return self._no_variable_creation_fn(*args, **kwds)  # pylint: disable=not-callable
#     927     elif self._variable_creation_fn is not None:
#     928       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py in __call__(self, *args, **kwargs)
#     141       (concrete_function,
#     142        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 143     return concrete_function._call_flat(
#     144         filtered_flat_args, captured_inputs=concrete_function.captured_inputs)  # pylint: disable=protected-access
#     145
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1755         and executing_eagerly):
#    1756       # No tape is watching; skip to running the function.
# -> 1757       return self._build_call_outputs(self._inference_function.call(
#    1758           ctx, args, cancellation_manager=cancellation_manager))
#    1759     forward_backward = self._select_forward_and_backward_functions(
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py in call(self, ctx, args, cancellation_manager)
#     379       with _InterpolateFunctionError(self):
#     380         if cancellation_manager is None:
# --> 381           outputs = execute.execute(
#     382               str(self.signature.name),
#     383               num_outputs=self._num_outputs,
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50   try:
#      51     ctx.ensure_initialized()
# ---> 52     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                         inputs, attrs, num_outputs)
#      54   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %% [markdown]
# Model 1 Evaluation on Test data

# %%
#model_1_results = model_1.evaluate(test_data)

model_1_results

# %% [markdown]
# # Fine Tune Model_1
#
# Key note: Fine tuning works best after training a feature extraction model for a few epochs with large amounts of custom data. Doing this will have the weights in the output layer trained.
#
# - Then work backwards and have the last layers of the feature extraction model (base model) trained on your custom data through fine tuning
#
# - Fine tined Model
#     - unfreeze base model's last few layers for them to be fine tuned on training data
#     - the top layers of the base model is learning the general features from the image

# %%
model_1.layers[2].trainable

# %% [markdown]
# #Fine Tune base model

# %% [markdown]
# ### View the number of trainable variables in model

# %%
print(len(model_1.trainable_variables))

# %% [markdown]
# ### View the number of trainable layers in model

# %%
for num, i in enumerate(model_1.layers):
    print(num, i, i.trainable)

# %% [markdown]
# ### View Model_1's Base Model( EfficientNetB0) layers

# %%
for num, layer in enumerate(model_1.layers[2].layers):
        print (num, layer.name, layer.trainable)

# %% [markdown]
# ### Modify Model_1's base model
# - Set layers to untrainable, except last 10

# %%
base_model.trainable = True

for num, layer in enumerate(model_1.layers[2].layers[:-10]):
    layer.trainable = False
    print(num, layer.name, layer.trainable)

# %% [markdown]
# ## Recompile Model_1
#
# - Model has to be recompiled whenever there is a change
#
# Key Note: Because we are updating already learned weights/patterns, its a good rule of thumb to not have those weights/patterns be updated too much. We dont want to change the patterns it has learned in the first fitting too much due to the risk of overfitting.
#
# The defailt lr in Adam is 0.001, Rule of thumb when fine tuning, to time it by 10X, therefore lr should be .0001
#
# learning_rate = dictates how much a model should update its internal patterns/weights eopoch to epoch or sample to sample depending on the loss & optimizer
# determines how much the model should learn

# %%
model_1.compile(loss =tf.keras.losses.SparseCategoricalCrossentropy(),
             optimizer = tf.keras.optimizers.Adam(lr = 0.0001),
             metrics="accuracy")

# %%
for num, layer in enumerate(model_1.layers[2].layers):
    
    print(num, layer.name, layer.trainable)

# %% [markdown]
# ### View the number of trainable variables in model

# %%
print(len(model_1.trainable_variables))

# %% [markdown]
# # Fit Model_1 Finetuned

# %%
fine_tune_epochs = initial_epochs + 5
model_1_history_fine_tuned = model_1.fit(train_data, 
                                                     epochs=fine_tune_epochs,
                                                     steps_per_epoch=len(train_data),
                                                     validation_data=test_data,
                                                     validation_steps=int(0.25 * len(test_data)),
                                                      initial_epoch= model_1_history.epoch[-1], #access the last epoch from model_1_history and starts from thre
                                                     callbacks=[create_tensorboard_callback("training_logs", 
                                                                                            "Model_1_efficientnetb0_feature_extract_fine_tune"),
                                                                model_checkpoint,
                                                               model_early_stopping])

# %%
model_1_results_fine_tune = model_1.evaluate(test_data)

# %% [markdown]
# # Visualize Model Performance

# %%
compare_historys(model_1_history,model_1_history_fine_tuned)

# %% [markdown]
# # Observation:
#   - Fine tuning has decreased Loss and improved accuracy

# %% [markdown]
# # Create Model_2
# - without data augmentation

# %% [markdown]
# # Model_2 Callbacks

# %%
#import tensorboard_callback from helper functions
from helper_functions import create_tensorboard_callback
 

#create model checkpoint
model_2_checkpoint_path = "model_checkpoints/cp.ckpt"
model_2_checkpoint = tf.keras.callbacks.ModelCheckpoint(model_2_checkpoint_path,
                                                     monitor = "val_acc",
                                                     save_weights_only=True,
                                                     verbose = 1)


model_2_early_stopping = tf.keras.callbacks.EarlyStopping(monitor="val_accuracy",
                                                 patience=3)

# %% [markdown]
# Create Model_2

# %%
from tensorflow.keras import layers
from tensorflow.keras.layers.experimental import preprocessing

#create base model
input_shape = (224,224,3)
base_model = tf.keras.applications.EfficientNetB0(include_top=False)
#set to false because we are customizing model (adding more layers) 
 
base_model.trainable = False
#when training our model with train data, we want the feature extraction model 
#to keep that preexisting patters not get trained more


#Create Functional model 

inputs = tf.keras.layers.Input(shape=input_shape, name = "input_layer")
print(inputs.shape)


#note: efficientnet has sclaing built in, if that was not the case
#x = preprocessing.Rescaling(1./255)(inputs)

x = base_model(inputs, training = False) #setting model as inference again
print(x.shape)


x = tf.keras.layers.GlobalAveragePooling2D(name = "global_average_pooling_layer")(x)
print(x.shape)


x = layers.Dense(len(class_names))(x) 
# one neuron per class 

# Separate activation of output layer so we can output float32 activations
outputs = layers.Activation("softmax", dtype=tf.float32, name="softmax_float32")(x) 

model_2 = tf.keras.Model(inputs, outputs)

# %% [markdown]
# # Compile Model_2

# %%
model_2.compile(loss = tf.keras.losses.SparseCategoricalCrossentropy(),
             optimizer = tf.keras.optimizers.Adam(),
             metrics="accuracy")

# %%
model_2.summary()

# %% [markdown]
# # Fit Model_2

# %%
# Turn off all warnings except for errors
tf.get_logger().setLevel('ERROR')


initial_epochs = 5
model_2_history = model_2.fit(train_data, 
                                                     epochs=initial_epochs,
                                                     steps_per_epoch=len(train_data),
                                                     validation_data=test_data,
                                                     validation_steps=int(0.25 * len(test_data)),
                                                     callbacks=[create_tensorboard_callback("training_logs", 
                                                                                            "Model_2_efficientnetb0_feature_extract"),
                                                                model_2_checkpoint,
                                                               model_2_early_stopping])

# %%
model_2_results = model_2.evaluate(test_data)

# %% [markdown]
# # Fine Tune Model_2
#
# Key note: Fine tuning works best after training a feature extraction model for a few epochs with large amounts of custom data. Doing this will have the weights in the output layer trained.
#
# - Then work backwards and have the last layers of the feature extraction model (base model) trained on your custom data through fine tuning
#
# - Fine tined Model
#     - unfreeze base model's last few layers for them to be fine tuned on training data
#     - the top layers of the base model is learning the general features from the image

# %%
model_2.layers[1].trainable

# %% [markdown]
# ### View the number of trainable variables in model

# %%
print(len(model_2.trainable_variables))

# %% [markdown]
# ### View the number of trainable layers in model_2

# %%
for num, i in enumerate(model_2.layers):
    print(num, i, i.trainable)

# %% [markdown]
# ### View Model_2's Base Model( EfficientNetB0) layers

# %%
for num, layer in enumerate(model_2.layers[1].layers):
        print (num, layer.name, layer.trainable)

# %% [markdown]
# ### Modify Model_1's base model
# - Set layers to untrainable, except last 10

# %%
base_model.trainable = True

for num, layer in enumerate(model_2.layers[1].layers[:-10]):
    layer.trainable = False
    print(num, layer.name, layer.trainable)

# %% [markdown]
# ## Recompile Model_2
#
# - Model has to be recompiled whenever there is a change
#
# Key Note: Because we are updating already learned weights/patterns, its a good rule of thumb to not have those weights/patterns be updated too much. We dont want to change the patterns it has learned in the first fitting too much due to the risk of overfitting.
#
# The defailt lr in Adam is 0.001, Rule of thumb when fine tuning, to time it by 10X, therefore lr should be .0001
#
# learning_rate = dictates how much a model should update its internal patterns/weights eopoch to epoch or sample to sample depending on the loss & optimizer
# determines how much the model should learn

# %%
model_2.compile(loss =tf.keras.losses.SparseCategoricalCrossentropy(),
             optimizer = tf.keras.optimizers.Adam(learning_rate = 0.0001),
             metrics="accuracy")

# %% [markdown]
# ### View Model_2's Base Model( EfficientNetB0) layers

# %%
for num, layer in enumerate(model_2.layers[1].layers):
        print (num, layer.name, layer.trainable)

# %% [markdown]
# ### View the number of trainable variables in model

# %%
print(len(model_2.trainable_variables))

# %% [markdown]
# # Fit Model_2 Finetuned

# %%
fine_tune_epochs = initial_epochs + 5
model_2_history_fine_tuned = model_2.fit(train_data, 
                                                     epochs=fine_tune_epochs,
                                                     steps_per_epoch=len(train_data),
                                                     validation_data=test_data,
                                                     validation_steps=int(0.25 * len(test_data)),
                                                      initial_epoch= model_2_history.epoch[-1], #access the last epoch from model_1_history and starts from thre
                                                     callbacks=[create_tensorboard_callback("training_logs", 
                                                                                            "Model_2_efficientnetb0_feature_extract_fine_tune"),
                                                                model_2_checkpoint,
                                                               model_2_early_stopping])

# %%
#model_2_results_fine_tuned = model_2.evaluate(test_data)

# %%
from helper_functions import compare_historys

# %% [markdown]
# # Visualize both Model's Performance

# %%
compare_historys(model_1_history, model_1_history_fine_tuned)

# %%
compare_historys(model_2_history, model_2_history_fine_tuned)

# %% [markdown]
# Observation:
#   - Fine tuning has decreased Loss and improved Accuracy for both models
#   - Model_2 has performed better than Model_1 without data augmention
